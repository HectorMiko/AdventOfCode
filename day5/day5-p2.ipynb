# %%
with open('day5.txt') as f:
    lines = f.read()
    data = lines.split("\n")

"""
transformations : {src: number, dest: number, len: number}[]
range_seed: {start: number, end: number}

def split_and_transform(range_seed, transformation):
    # algo which split into n range_seed depending on transformations
    # hard part

temp_seed_ranges = original_seed_ranges
for transformation in transformations:
    new_seed_ranges = []
    for range_seed in temp_seed_ranges:
        new_seed_ranges = split_and_transform(range_seed, transformation)
    temp_seed_range = new_seed_ranges
        
minimal_seed = min([s["start"] for s in temp_seed_range])

"""
# Out:
# '\ntransformations : {src: number, dest: number, len: number}[]\nrange_seed: {start: number, end: number}\n\ndef split_and_transform(range_seed, transformation):\n    # algo which split into n range_seed depending on transformations\n    # hard part\n\ntemp_seed_ranges = original_seed_ranges\nfor transformation in transformations:\n    new_seed_ranges = []\n    for range_seed in temp_seed_ranges:\n        new_seed_ranges = split_and_transform(range_seed, transformation)\n    temp_seed_range = new_seed_ranges\n        \nminimal_seed = min([s["start"] for s in temp_seed_range])\n\n'

# %%
def create_ranges(src_dest_ranges) -> None:
    ranges = []
    for src_dest_range in src_dest_ranges:
        ranges.append(createNewRange(src_dest_range))
    return ranges

def createNewRange(src_dest_range):
    # print("src_dest_range", src_dest_range)
    dest, src , len = src_dest_range.split()
    return { "src": int(src), "dest": int(dest), "len": int(len), "start": int(src), "end": int(src)+int(len)-1}

def transformNumber(ranges, number_input):
    new_value = number_input
    for r in ranges:
        if (
            r["src"] <= number_input 
            and number_input<r["src"]+r["len"]
        ):
            new_value = r["dest"]+(number_input-r["src"])
    return new_value

# %%
STEPS = ["seed-to-soil map:", "soil-to-fertilizer map:", "fertilizer-to-water map:", "water-to-light map:", "light-to-temperature map:", "temperature-to-humidity map:", "humidity-to-location map:"]
buffer_ranges = []
transformations = []
for line in data:
    if "seeds:" in line:
        seeds= [int(i) for i in line.split()[1:]]
    elif line in STEPS:
        pass
    elif len(line)==0  and len(buffer_ranges)!=0:
        print("buffer_ranges", buffer_ranges)
        t = create_ranges(buffer_ranges)
        transformations.append(t)
        del(buffer_ranges)
        buffer_ranges = []
    elif len(line):
        buffer_ranges.append(line)
t = create_ranges(buffer_ranges)
transformations.append(t)

original_seed_ranges = []
for i in range(len(seeds)):
    if i%2==1:
        continue
    original_seed_ranges.append({
        "start": int(seeds[i]),
        "end": int(seeds[i])+int(seeds[i+1]),
    })
# Out:
# buffer_ranges ['1393363309 644938450 159685707', '2025282601 1844060172 19312202', '1233103806 1026919253 32871092', '1086566452 1933428941 86530991', '1265974898 0 21589659', '1357621124 1636167265 35742185', '2343571960 2665606060 81121142', '1585337376 809179011 202497192', '3151050390 3039622538 54531851', '2059837853 804624157 4554854', '169037772 124717914 59280146', '228317918 183998060 248114943', '2646529073 2343571960 51673623', '1173097443 1360585007 60006363', '2000660015 1203115155 24622586', '1059486394 1176035097 27080058', '3129081851 4185259485 17367169', '3599437884 3098755759 211817367', '2810085327 3883695720 116314513', '2424693102 4015066563 32329632', '3398847262 2507128214 141172870', '1787834568 432113003 212825447', '1553049016 1603878905 32288360', '3111414816 4202626654 17667035', '4015961437 3493485543 279005859', '3584381554 4000010233 15056330', '609280127 1840486939 3573233', '0 1603418622 460283', '3302297495 3310573126 79244791', '3811255251 4047396195 137863290', '3381542286 2648301084 17304976', '3280255848 3389817917 22041647', '840113387 21589659 103128
'src': 3310573126, 'dest': 3302297495, 'len': 79244791, 'start': 3310573126, 'end': 3389817916}, {'src': 4047396195, 'dest': 3811255251, 'len': 137863290, 'start': 4047396195, 'end': 4185259484}, {'src': 2648301084, 'dest': 3381542286, 'len': 17304976, 'start': 2648301084, 'end': 2665606059}, {'src': 3389817917, 'dest': 3280255848, 'len': 22041647, 'start': 3389817917, 'end': 3411859563}, {'src': 21589659, 'dest': 840113387, 'len': 103128255, 'start': 21589659, 'end': 124717913}, {'src': 3816852824, 'dest': 3949118541, 'len': 66842896, 'start': 3816852824, 'end': 3883695719}, {'src': 4220293689, 'dest': 3205582241, 'len': 74673607, 'start': 4220293689, 'end': 4294967295}, {'src': 1420591370, 'dest': 657286135, 'len': 182827252, 'start': 1420591370, 'end': 1603418621}, {'src': 1863372374, 'dest': 1287564557, 'len': 70056567, 'start': 1863372374, 'end': 1933428940}, {'src': 1671909450, 'dest': 460283, 'len': 168577489, 'start': 1671909450, 'end': 1840486938}, {'src': 2746727202, 'dest': 2926399840, 'len': 103388997, 'start': 2746727202, 'end': 2850116198}, {'src': 3094154389, 'dest': 3146449020, 'len': 4601370, 'start': 3094154389, 'end': 3098755758}, {'src': 1059790345, 'dest': 943241642, 'len': 116244752, 'start': 1059790345, 'end': 1176035096}, {'src': 1227737741, 'dest': 4764 ...

# %%
def split_and_transform(range_seed, transformation):
    # algo which split into n range_seed depending on transformations
    split_seeds = []
    temp_split = range_seed
    for t in transformation:
        # 5 cases : 
        # * absolutly out before
        if temp_split["end"]<t["start"]:
            split_seeds.append(temp_split)
            return split_seeds
        # * eating start
        elif temp_split["start"]<t["start"] and temp_split["end"]>=t["start"] and temp_split["end"]<=t["end"]:
            split_seeds.append({ 
                "start": temp_split["start"],
                "end": t["start"]-1
            }) 
            split_seeds.append({
                "start": t["start"],
                "end": temp_split["end"]
            })
            return split_seeds

        # * in the middle
        elif temp_split["start"]>=t["start"] and temp_split["end"]<=t["end"]:
            split_seeds.append({
                "start": temp_split["start"],
                "end": temp_split["end"]
            })
            return split_seeds
        
        # * over the total range
        elif temp_split["start"]<t["start"] and temp_split["end"]>t["end"]:
            split_seeds.append({ 
                "start": temp_split["start"],
                "end": t["start"]-1
            })
            split_seeds.append({ 
                "start": t["start"],
                "end": t["end"]
            })
            temp_split = {
                "start": t["end"]+1,
                "end": temp_split["end"]
            }

        # * eating end
        elif temp_split["start"]>=t["start"] and temp_split["start"]<=t["end"] and temp_split["end"]>t["end"]:
            split_seeds.append({ 
                "start": temp_split["start"],
                "end": t["end"]
            })
            temp_split = {
                "start": t["end"]+1,
                "end": temp_split["end"]
            }
        # * absolutly out after
        # elif temp_split["start"]>t["end"]:
        #     DO NOTHING HERE

    split_seeds.append({
        "start": temp_split["start"],
        "end": temp_split["end"]
    })
    return split_seeds

temp_seed_ranges = original_seed_ranges
for transformation in transformations:
    transformation = sorted(transformation, key=lambda x: x['src'])
    split_seed_list = []
    for seed in temp_seed_ranges:
        split_seed = split_and_transform(seed, transformation)
        split_seed_list += split_seed
    transformedList = []
    for split in split_seed_list:
        transformedList.append({
            "start": transformNumber(transformation, split["start"]),
            "end": transformNumber(transformation, split["end"])
        })

    temp_seed_ranges = transformedList


minimal_seed = min([s["start"] for s in temp_seed_ranges])
print(minimal_seed)
# Out:
# 37384986
